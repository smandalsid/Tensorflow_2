# %% [markdown]
# changing batch size and epochs

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# network and training
EPOCHS = 20
BATCH_SIZE = 256
VERBOSE = 1
NB_CLASSES = 10   # number of outputs = number of digits
N_HIDDEN = 128
VALIDATION_SPLIT=0.2 # how much TRAIN is reserved for VALIDATION
DROPOUT = 0.3

# loading MNIST dataset
# verify
# the split between train and test is 60,000, and 10,000 respectly
# one-hot is automatically applied
mnist = keras.datasets.mnist
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

#X_train is 60000 rows of 28x28 values --> reshaped in 60000 x 784
RESHAPED = 784
#
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

#normalize in [0,1]
X_train, X_test = X_train / 255.0, X_test / 255.0
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

#one-hot
Y_train = tf.keras.utils.to_categorical(Y_train, NB_CLASSES)
Y_test = tf.keras.utils.to_categorical(Y_test, NB_CLASSES)

#build the model
model = tf.keras.models.Sequential()
model.add(keras.layers.Dense(N_HIDDEN,
   		input_shape=(RESHAPED,),
   		name='dense_layer', activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(N_HIDDEN,
   		name='dense_layer_2', activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(NB_CLASSES,
   		name='dense_layer_3', activation='softmax'))

# summary of the model
model.summary()

# compiling the model
model.compile(optimizer='Adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

#training the moodel
r=model.fit(X_train, Y_train,
		batch_size=BATCH_SIZE, epochs=EPOCHS,
		verbose=VERBOSE, validation_split=VALIDATION_SPLIT)
# Out:
# 60000 train samples
# 10000 test samples
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_layer (Dense)         (None, 128)               100480
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_layer_2 (Dense)       (None, 128)               16512
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_layer_3 (Dense)       (None, 10)                1290
#
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 188/188 [==============================] - 2s 6ms/step - loss: 0.6294 - accuracy: 0.8046 - val_loss: 0.2157 - val_accuracy: 0.9365
# Epoch 2/20
# 188/188 [==============================] - 1s 5ms/step - loss: 0.2704 - accuracy: 0.9195 - val_loss: 0.1558 - val_accuracy: 0.9534
# Epoch 3/20
# 188/188 [==============================] - 1s 5ms/step - loss: 0.2054 - accuracy: 0.9380 - val_loss: 0.1321 - val_accuracy: 0.9604
# Epoch 4/20
# 188/188 [==============================] - 1s 5ms/step - loss: 0.1764 - accuracy: 0.9473 - val_loss: 0.1177 - val_accuracy: 0.9651
# Epoch 5/20
# 188/188 [==============================] - 1s 7ms/step - loss: 0.1504 - accuracy: 0.9548 - val_loss: 0.1103 - val_accuracy: 0.9666
# Epoch 6/20
# 188/188 [==============================] - 1s 8ms/step - loss: 0.1369 - accuracy: 0.9583 - val_loss: 0.1005 - val_accuracy: 0.9688
# Epoch 7/20
# 188/188 [==============================] - 2s 8ms/step - loss: 0.1225 - accuracy: 0.9639 - val_loss: 0.0978 - val_accuracy: 0.9712
# Epoch 8/20
# 188/188 [==============================] - 2s 10ms/step - loss: 0.1118 - accuracy: 0.9654 - val_loss: 0.0939 - val_accuracy: 0.9720
# Epoch 9/20
# 188/188 [==============================] - 3s 14ms/step - loss: 0.1039 - accuracy: 0.9682 - val_loss: 0.0971 - val_accuracy: 0.9719
# Epoch 10/20
# 188/188 [==============================] - 2s 11ms/step - loss: 0.0972 - accuracy: 0.9696 - val_loss: 0.0909 - val_accuracy: 0.9747
# Epoch 11/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.0927 - accuracy: 0.9710 - val_loss: 0.0863 - val_accuracy: 0.9748
# Epoch 12/20
# 188/188 [==============================] - 2s 8ms/step - loss: 0.0862 - accuracy: 0.9726 - val_loss: 0.0915 - val_accuracy: 0.9732
# Epoch 13/20
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0805 - accuracy: 0.9742 - val_loss: 0.0847 - val_accuracy: 0.9747
# Epoch 14/20
# 188/188 [==============================] - 1s 5ms/step - loss: 0.0772 - accuracy: 0.9749 - val_loss: 0.0826 - val_accuracy: 0.9750
# Epoch 15/20
# 188/188 [==============================] - 1s 5ms/step - loss: 0.0739 - accuracy: 0.9766 - val_loss: 0.0826 - val_accuracy: 0.9770
# Epoch 16/20
# 188/188 [==============================] - 1s 4ms/step - loss: 0.0694 - accuracy: 0.9778 - val_loss: 0.0817 - val_accuracy: 0.9768
# Epoch 17/20
# 188/188 [==============================] - 1s 4ms/step - loss: 0.0660 - accuracy: 0.9783 - val_loss: 0.0843 - val_accuracy: 0.9759
# Epoch 18/20
# 188/188 [==============================] - 1s 5ms/step - loss: 0.0652 - accuracy: 0.9790 - val_loss: 0.0807 - val_accuracy: 0.9771
# Epoch 19/20
# 188/188 [==============================] - 1s 7ms/step - loss: 0.0598 - accuracy: 0.9803 - val_loss: 0.0825 - val_accuracy: 0.9769
# Epoch 20/20
# 188/188 [==============================] - 1s 6ms/step - loss: 0.0620 - accuracy: 0.9799 - val_loss: 0.0845 - val_accuracy: 0.9772

# %%
#evalute the model
test_loss, test_acc = model.evaluate(X_test, Y_test)
print('Test accuracy:', test_acc)

# making prediction
predictions = model.predict(X_test)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0783 - accuracy: 0.9783
# Test accuracy: 0.9782999753952026
# 313/313 [==============================] - 1s 2ms/step

# %%
import matplotlib.pyplot as plt
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend(loc="upper right")
plt.show()

# %%
plt.plot(r.history['accuracy'], label='acc')
plt.plot(r.history['val_accuracy'], label='val_acc')
plt.legend(loc="upper right")
plt.show()
