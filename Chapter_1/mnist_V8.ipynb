# %% [markdown]
# different learning rates

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
from tensorflow.keras.optimizers import SGD

# network and training
EPOCHS = 20
BATCH_SIZE = 256
VERBOSE = 1
NB_CLASSES = 10   # number of outputs = number of digits
N_HIDDEN = 128
VALIDATION_SPLIT=0.2 # how much TRAIN is reserved for VALIDATION
DROPOUT = 0.3
OPTMIZER = SGD(lr=0.001)

# loading MNIST dataset
# verify
# the split between train and test is 60,000, and 10,000 respectly
# one-hot is automatically applied
mnist = keras.datasets.mnist
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

#X_train is 60000 rows of 28x28 values --> reshaped in 60000 x 784
RESHAPED = 784
#
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

#normalize in [0,1]
X_train, X_test = X_train / 255.0, X_test / 255.0
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

#one-hot
Y_train = tf.keras.utils.to_categorical(Y_train, NB_CLASSES)
Y_test = tf.keras.utils.to_categorical(Y_test, NB_CLASSES)

#build the model
model = tf.keras.models.Sequential()
model.add(keras.layers.Dense(N_HIDDEN,
   		input_shape=(RESHAPED,),
   		name='dense_layer', activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(N_HIDDEN,
   		name='dense_layer_2', activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(NB_CLASSES,
   		name='dense_layer_3', activation='softmax'))

# summary of the model
model.summary()

# compiling the model
model.compile(optimizer=OPTMIZER,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

#training the moodel
r=model.fit(X_train, Y_train,
		batch_size=BATCH_SIZE, epochs=EPOCHS,
		verbose=VERBOSE, validation_split=VALIDATION_SPLIT)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# 60000 train samples
# 10000 test samples
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_layer (Dense)         (None, 128)               100480
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_layer_2 (Dense)       (None, 128)               16512
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_layer_3 (Dense)       (None, 10)                1290
#
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 188/188 [==============================] - 8s 6ms/step - loss: 2.0659 - accuracy: 0.3140 - val_loss: 1.6381 - val_accuracy: 0.6632
# Epoch 2/20
# 188/188 [==============================] - 1s 4ms/step - loss: 1.4475 - accuracy: 0.5785 - val_loss: 0.9468 - val_accuracy: 0.8067
# Epoch 3/20
# 188/188 [==============================] - 1s 4ms/step - loss: 1.0320 - accuracy: 0.6865 - val_loss: 0.6551 - val_accuracy: 0.8517
# Epoch 4/20
# 188/188 [==============================] - 1s 5ms/step - loss: 0.8404 - accuracy: 0.7399 - val_loss: 0.5323 - val_accuracy: 0.8702
# Epoch 5/20
# 188/188 [==============================] - 1s 4ms/step - loss: 0.7291 - accuracy: 0.7750 - val_loss: 0.4628 - val_accuracy: 0.8824
# Epoch 6/20
# 188/188 [==============================] - 1s 5ms/step - loss: 0.6560 - accuracy: 0.7981 - val_loss: 0.4181 - val_accuracy: 0.8905
# Epoch 7/20
# 188/188 [==============================] - 1s 4ms/step - loss: 0.6096 - accuracy: 0.8131 - val_loss: 0.3907 - val_accuracy: 0.8939
# Epoch 8/20
# 188/188 [==============================] - 1s 5ms/step - loss: 0.5685 - accuracy: 0.8275 - val_loss: 0.3658 - val_accuracy: 0.9003
# Epoch 9/20
# 188/188 [==============================] - 1s 4ms/step - loss: 0.5350 - accuracy: 0.8392 - val_loss: 0.3477 - val_accuracy: 0.9039
# Epoch 10/20
# 188/188 [==============================] - 1s 4ms/step - loss: 0.5137 - accuracy: 0.8463 - val_loss: 0.3324 - val_accuracy: 0.9072
# Epoch 11/20
# 188/188 [==============================] - 1s 6ms/step - loss: 0.4930 - accuracy: 0.8523 - val_loss: 0.3198 - val_accuracy: 0.9089
# Epoch 12/20
# 188/188 [==============================] - 1s 7ms/step - loss: 0.4730 - accuracy: 0.8588 - val_loss: 0.3087 - val_accuracy: 0.9127
# Epoch 13/20
# 188/188 [==============================] - 1s 4ms/step - loss: 0.4569 - accuracy: 0.8645 - val_loss: 0.2992 - val_accuracy: 0.9142
# Epoch 14/20
# 188/188 [==============================] - 1s 4ms/step - loss: 0.4410 - accuracy: 0.8691 - val_loss: 0.2904 - val_accuracy: 0.9168
# Epoch 15/20
# 188/188 [==============================] - 1s 4ms/step - loss: 0.4280 - accuracy: 0.8728 - val_loss: 0.2825 - val_accuracy: 0.9183
# Epoch 16/20
# 188/188 [==============================] - 1s 5ms/step - loss: 0.4177 - accuracy: 0.8769 - val_loss: 0.2755 - val_accuracy: 0.9201
# Epoch 17/20
# 188/188 [==============================] - 1s 5ms/step - loss: 0.4057 - accuracy: 0.8803 - val_loss: 0.2685 - val_accuracy: 0.9214
# Epoch 18/20
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3964 - accuracy: 0.8840 - val_loss: 0.2624 - val_accuracy: 0.9231
# Epoch 19/20
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3853 - accuracy: 0.8864 - val_loss: 0.2562 - val_accuracy: 0.9252
# Epoch 20/20
# 188/188 [==============================] - 1s 4ms/step - loss: 0.3795 - accuracy: 0.8891 - val_loss: 0.2524 - val_accuracy: 0.9262

# %%
#evalute the model
test_loss, test_acc = model.evaluate(X_test, Y_test)
print('Test accuracy:', test_acc)

# making prediction
predictions = model.predict(X_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2541 - accuracy: 0.9287
# Test accuracy: 0.9286999702453613
# 313/313 [==============================] - 1s 2ms/step

# %%
import matplotlib.pyplot as plt
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend(loc="upper right")
plt.show()

# %%
plt.plot(r.history['accuracy'], label='acc')
plt.plot(r.history['val_accuracy'], label='val_acc')
plt.legend(loc="upper right")
plt.show()
