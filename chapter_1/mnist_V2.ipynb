# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# network and training
EPOCHS = 50
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10   # number of outputs = number of digits
N_HIDDEN = 128
VALIDATION_SPLIT=0.2 # how much TRAIN is reserved for VALIDATION

# loading MNIST dataset
# verify
# the split between train and test is 60,000, and 10,000 respectly
# one-hot is automatically applied
mnist = keras.datasets.mnist
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

#X_train is 60000 rows of 28x28 values --> reshaped in 60000 x 784
RESHAPED = 784
#
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

#normalize in [0,1]
X_train, X_test = X_train / 255.0, X_test / 255.0
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

#one-hot
Y_train = tf.keras.utils.to_categorical(Y_train, NB_CLASSES)
Y_test = tf.keras.utils.to_categorical(Y_test, NB_CLASSES)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# 60000 train samples
# 10000 test samples

# %% [markdown]
# # **ADDING HIDDEN LAYER**

# %%
#build the model
model = tf.keras.models.Sequential()
model.add(keras.layers.Dense(N_HIDDEN,
   		input_shape=(RESHAPED,),
   		name='dense_layer', activation='relu'))
model.add(keras.layers.Dense(N_HIDDEN,
   		name='dense_layer_2', activation='relu'))
model.add(keras.layers.Dense(NB_CLASSES,
   		name='dense_layer_3', activation='softmax'))

# %%
# summary of the model
model.summary()

# compiling the model
model.compile(optimizer='SGD',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_layer (Dense)         (None, 128)               100480
#
#  dense_layer_2 (Dense)       (None, 128)               16512
#
#  dense_layer_3 (Dense)       (None, 10)                1290
#
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________

# %%
#training the model
r=model.fit(X_train, Y_train,
		batch_size=BATCH_SIZE, epochs=EPOCHS,
		verbose=VERBOSE, validation_split=VALIDATION_SPLIT)
# Out:
# Epoch 1/50
# 375/375 [==============================] - 3s 6ms/step - loss: 1.4078 - accuracy: 0.6600 - val_loss: 0.7097 - val_accuracy: 0.8447
# Epoch 2/50
# 375/375 [==============================] - 2s 6ms/step - loss: 0.5733 - accuracy: 0.8562 - val_loss: 0.4377 - val_accuracy: 0.8851
# Epoch 3/50
# 375/375 [==============================] - 3s 7ms/step - loss: 0.4263 - accuracy: 0.8836 - val_loss: 0.3657 - val_accuracy: 0.8972
# Epoch 4/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3711 - accuracy: 0.8958 - val_loss: 0.3296 - val_accuracy: 0.9064
# Epoch 5/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3393 - accuracy: 0.9031 - val_loss: 0.3064 - val_accuracy: 0.9128
# Epoch 6/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3172 - accuracy: 0.9091 - val_loss: 0.2909 - val_accuracy: 0.9153
# Epoch 7/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3001 - accuracy: 0.9147 - val_loss: 0.2764 - val_accuracy: 0.9205
# Epoch 8/50
# 375/375 [==============================] - 2s 7ms/step - loss: 0.2859 - accuracy: 0.9181 - val_loss: 0.2661 - val_accuracy: 0.9227
# Epoch 9/50
# 375/375 [==============================] - 3s 7ms/step - loss: 0.2737 - accuracy: 0.9218 - val_loss: 0.2566 - val_accuracy: 0.9258
# Epoch 10/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2628 - accuracy: 0.9254 - val_loss: 0.2478 - val_accuracy: 0.9297
# Epoch 11/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2530 - accuracy: 0.9277 - val_loss: 0.2393 - val_accuracy: 0.9324
# Epoch 12/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2441 - accuracy: 0.9311 - val_loss: 0.2317 - val_accuracy: 0.9332
# Epoch 13/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2360 - accuracy: 0.9327 - val_loss: 0.2253 - val_accuracy: 0.9375
# Epoch 14/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2281 - accuracy: 0.9343 - val_loss: 0.2230 - val_accuracy: 0.9365
# Epoch 15/50
# 375/375 [==============================] - 4s 10ms/step - loss: 0.2213 - accuracy: 0.9370 - val_loss: 0.2133 - val_accuracy: 0.9407
# Epoch 16/50
# 375/375 [==============================] - 3s 7ms/step - loss: 0.2148 - accuracy: 0.9388 - val_loss: 0.2081 - val_accuracy: 0.9419
# Epoch 17/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2086 - accuracy: 0.9408 - val_loss: 0.2033 - val_accuracy: 0.9435
# Epoch 18/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2025 - accuracy: 0.9416 - val_loss: 0.1978 - val_accuracy: 0.9446
# Epoch 19/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1971 - accuracy: 0.9433 - val_loss: 0.1938 - val_accuracy: 0.9454
# Epoch 20/50
# 375/375 [==============================] - 3s 8ms/step - loss: 0.1917 - accuracy: 0.9451 - val_loss: 0.1894 - val_accuracy: 0.9468
# Epoch 21/50
# 375/375 [==============================] - 2s 6ms/step - loss: 0.1868 - accuracy: 0.9465 - val_loss: 0.1867 - val_accuracy: 0.9482
# Epoch 22/50
# 375/375 [==============================] - 2s 6ms/step - loss: 0.1820 - accuracy: 0.9478 - val_loss: 0.1812 - val_accuracy: 0.9492
# Epoch 23/50
# 375/375 [==============================] - 2s 6ms/step - loss: 0.1774 - accuracy: 0.9491 - val_loss: 0.1784 - val_accuracy: 0.9502
# Epoch 24/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1731 - accuracy: 0.9501 - val_loss: 0.1756 - val_accuracy: 0.9508
# Epoch 25/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1689 - accuracy: 0.9516 - val_loss: 0.1727 - val_accuracy: 0.9517
# Epoch 26/50
# 375/375 [==============================] - 3s 8ms/step - loss: 0.1650 - accuracy: 0.9528 - val_loss: 0.1683 - val_accuracy: 0.9525
# Epoch 27/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1612 - accuracy: 0.9535 - val_loss: 0.1660 - val_accuracy: 0.9532
# Epoch 28/50
# 375/375 [==============================] - 2s 7ms/step - loss: 0.1575 - accuracy: 0.9548 - val_loss: 0.1629 - val_accuracy: 0.9544
# Epoch 29/50
# 375/375 [==============================] - 3s 9ms/step - loss: 0.1541 - accuracy: 0.9561 - val_loss: 0.1593 - val_accuracy: 0.9559
# Epoch 30/50
# 375/375 [==============================] - 5s 12ms/step - loss: 0.1506 - accuracy: 0.9568 - val_loss: 0.1569 - val_accuracy: 0.9565
# Epoch 31/50
# 375/375 [==============================] - 4s 11ms/step - loss: 0.1473 - accuracy: 0.9578 - val_loss: 0.1547 - val_accuracy: 0.9574
# Epoch 32/50
# 375/375 [==============================] - 2s 6ms/step - loss: 0.1442 - accuracy: 0.9588 - val_loss: 0.1530 - val_accuracy: 0.9573
# Epoch 33/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1414 - accuracy: 0.9599 - val_loss: 0.1505 - val_accuracy: 0.9588
# Epoch 34/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1384 - accuracy: 0.9603 - val_loss: 0.1481 - val_accuracy: 0.9586
# Epoch 35/50
# 375/375 [==============================] - 3s 8ms/step - loss: 0.1358 - accuracy: 0.9613 - val_loss: 0.1462 - val_accuracy: 0.9592
# Epoch 36/50
# 375/375 [==============================] - 3s 9ms/step - loss: 0.1330 - accuracy: 0.9623 - val_loss: 0.1449 - val_accuracy: 0.9581
# Epoch 37/50
# 375/375 [==============================] - 3s 8ms/step - loss: 0.1304 - accuracy: 0.9628 - val_loss: 0.1433 - val_accuracy: 0.9591
# Epoch 38/50
# 375/375 [==============================] - 2s 7ms/step - loss: 0.1278 - accuracy: 0.9635 - val_loss: 0.1418 - val_accuracy: 0.9609
# Epoch 39/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1255 - accuracy: 0.9640 - val_loss: 0.1394 - val_accuracy: 0.9607
# Epoch 40/50
# 375/375 [==============================] - 3s 8ms/step - loss: 0.1230 - accuracy: 0.9651 - val_loss: 0.1378 - val_accuracy: 0.9615
# Epoch 41/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1209 - accuracy: 0.9657 - val_loss: 0.1362 - val_accuracy: 0.9611
# Epoch 42/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1186 - accuracy: 0.9669 - val_loss: 0.1342 - val_accuracy: 0.9622
# Epoch 43/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1164 - accuracy: 0.9669 - val_loss: 0.1325 - val_accuracy: 0.9627
# Epoch 44/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1144 - accuracy: 0.9677 - val_loss: 0.1317 - val_accuracy: 0.9625
# Epoch 45/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1123 - accuracy: 0.9685 - val_loss: 0.1299 - val_accuracy: 0.9632
# Epoch 46/50
# 375/375 [==============================] - 3s 8ms/step - loss: 0.1103 - accuracy: 0.9690 - val_loss: 0.1282 - val_accuracy: 0.9637
# Epoch 47/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1085 - accuracy: 0.9695 - val_loss: 0.1284 - val_accuracy: 0.9642
# Epoch 48/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1066 - accuracy: 0.9701 - val_loss: 0.1257 - val_accuracy: 0.9647
# Epoch 49/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1049 - accuracy: 0.9703 - val_loss: 0.1247 - val_accuracy: 0.9656
# Epoch 50/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1029 - accuracy: 0.9712 - val_loss: 0.1240 - val_accuracy: 0.9643

# %%
#evaluate the model
test_loss, test_acc = model.evaluate(X_test, Y_test)
print('Test accuracy:', test_acc)

# making prediction
predictions = model.predict(X_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1196 - accuracy: 0.9642
# Test accuracy: 0.9642000198364258
# 313/313 [==============================] - 1s 2ms/step

# %%
import matplotlib.pyplot as plt
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend(loc="upper right")
plt.show()

# %%
plt.plot(r.history['accuracy'], label='acc')
plt.plot(r.history['val_accuracy'], label='val_acc')
plt.legend(loc="upper right")
plt.show()
