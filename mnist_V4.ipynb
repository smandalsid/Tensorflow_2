# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

#for tensorboard
from tensorflow.keras.callbacks import TensorBoard
tensorboard_callback = TensorBoard('.logdir')

# network and training
EPOCHS = 50
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10   # number of outputs = number of digits
N_HIDDEN = 128
VALIDATION_SPLIT=0.2 # how much TRAIN is reserved for VALIDATION
DROPOUT = 0.3

# loading MNIST dataset
# verify
# the split between train and test is 60,000, and 10,000 respectly
# one-hot is automatically applied
mnist = keras.datasets.mnist
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

#X_train is 60000 rows of 28x28 values --> reshaped in 60000 x 784
RESHAPED = 784
#
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

#normalize in [0,1]
X_train, X_test = X_train / 255.0, X_test / 255.0
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

#one-hot
Y_train = tf.keras.utils.to_categorical(Y_train, NB_CLASSES)
Y_test = tf.keras.utils.to_categorical(Y_test, NB_CLASSES)

#build the model
model = tf.keras.models.Sequential()
model.add(keras.layers.Dense(N_HIDDEN,
   		input_shape=(RESHAPED,),
   		name='dense_layer', activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(N_HIDDEN,
   		name='dense_layer_2', activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(NB_CLASSES,
   		name='dense_layer_3', activation='softmax'))

# summary of the model
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 2s 0us/step
# 60000 train samples
# 10000 test samples
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_layer (Dense)         (None, 128)               100480
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_layer_2 (Dense)       (None, 128)               16512
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_layer_3 (Dense)       (None, 10)                1290
#
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # **USING RMSProp optimizer**

# %%
# compiling the model
model.compile(optimizer='RMSProp',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
#training the moodel
r=model.fit(X_train, Y_train,
		batch_size=BATCH_SIZE, epochs=EPOCHS,
		verbose=VERBOSE, validation_split=VALIDATION_SPLIT,
		callbacks=[tensorboard_callback])
# Out:
# Epoch 1/50
# 375/375 [==============================] - 11s 7ms/step - loss: 0.4943 - accuracy: 0.8517 - val_loss: 0.1938 - val_accuracy: 0.9423
# Epoch 2/50
# 375/375 [==============================] - 3s 7ms/step - loss: 0.2322 - accuracy: 0.9304 - val_loss: 0.1478 - val_accuracy: 0.9571
# Epoch 3/50
# 375/375 [==============================] - 2s 7ms/step - loss: 0.1782 - accuracy: 0.9460 - val_loss: 0.1166 - val_accuracy: 0.9653
# Epoch 4/50
# 375/375 [==============================] - 3s 8ms/step - loss: 0.1516 - accuracy: 0.9543 - val_loss: 0.1083 - val_accuracy: 0.9682
# Epoch 5/50
# 375/375 [==============================] - 2s 6ms/step - loss: 0.1323 - accuracy: 0.9601 - val_loss: 0.1046 - val_accuracy: 0.9697
# Epoch 6/50
# 375/375 [==============================] - 2s 6ms/step - loss: 0.1164 - accuracy: 0.9645 - val_loss: 0.0990 - val_accuracy: 0.9721
# Epoch 7/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1090 - accuracy: 0.9669 - val_loss: 0.0953 - val_accuracy: 0.9728
# Epoch 8/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1037 - accuracy: 0.9698 - val_loss: 0.0945 - val_accuracy: 0.9742
# Epoch 9/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0978 - accuracy: 0.9719 - val_loss: 0.0960 - val_accuracy: 0.9753
# Epoch 10/50
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0900 - accuracy: 0.9732 - val_loss: 0.0912 - val_accuracy: 0.9759
# Epoch 11/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0859 - accuracy: 0.9740 - val_loss: 0.0947 - val_accuracy: 0.9762
# Epoch 12/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0836 - accuracy: 0.9748 - val_loss: 0.0885 - val_accuracy: 0.9768
# Epoch 13/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0793 - accuracy: 0.9757 - val_loss: 0.0926 - val_accuracy: 0.9764
# Epoch 14/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0768 - accuracy: 0.9765 - val_loss: 0.0914 - val_accuracy: 0.9760
# Epoch 15/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0738 - accuracy: 0.9775 - val_loss: 0.0948 - val_accuracy: 0.9745
# Epoch 16/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0716 - accuracy: 0.9774 - val_loss: 0.0944 - val_accuracy: 0.9762
# Epoch 17/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0698 - accuracy: 0.9795 - val_loss: 0.0936 - val_accuracy: 0.9761
# Epoch 18/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0684 - accuracy: 0.9793 - val_loss: 0.1000 - val_accuracy: 0.9771
# Epoch 19/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0663 - accuracy: 0.9798 - val_loss: 0.1000 - val_accuracy: 0.9786
# Epoch 20/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0663 - accuracy: 0.9794 - val_loss: 0.1036 - val_accuracy: 0.9760
# Epoch 21/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0651 - accuracy: 0.9808 - val_loss: 0.1045 - val_accuracy: 0.9774
# Epoch 22/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0611 - accuracy: 0.9817 - val_loss: 0.1038 - val_accuracy: 0.9778
# Epoch 23/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0601 - accuracy: 0.9809 - val_loss: 0.1078 - val_accuracy: 0.9772
# Epoch 24/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0594 - accuracy: 0.9819 - val_loss: 0.1052 - val_accuracy: 0.9771
# Epoch 25/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0590 - accuracy: 0.9821 - val_loss: 0.1009 - val_accuracy: 0.9774
# Epoch 26/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0556 - accuracy: 0.9823 - val_loss: 0.1018 - val_accuracy: 0.9787
# Epoch 27/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0565 - accuracy: 0.9829 - val_loss: 0.1041 - val_accuracy: 0.9789
# Epoch 28/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0533 - accuracy: 0.9833 - val_loss: 0.1120 - val_accuracy: 0.9752
# Epoch 29/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0539 - accuracy: 0.9840 - val_loss: 0.1010 - val_accuracy: 0.9779
# Epoch 30/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0522 - accuracy: 0.9835 - val_loss: 0.1130 - val_accuracy: 0.9784
# Epoch 31/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0503 - accuracy: 0.9846 - val_loss: 0.1099 - val_accuracy: 0.9783
# Epoch 32/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0525 - accuracy: 0.9844 - val_loss: 0.1135 - val_accuracy: 0.9772
# Epoch 33/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0522 - accuracy: 0.9848 - val_loss: 0.1066 - val_accuracy: 0.9783
# Epoch 34/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0518 - accuracy: 0.9844 - val_loss: 0.1063 - val_accuracy: 0.9782
# Epoch 35/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0503 - accuracy: 0.9845 - val_loss: 0.1147 - val_accuracy: 0.9780
# Epoch 36/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0492 - accuracy: 0.9853 - val_loss: 0.1169 - val_accuracy: 0.9789
# Epoch 37/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0508 - accuracy: 0.9859 - val_loss: 0.1161 - val_accuracy: 0.9778
# Epoch 38/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0524 - accuracy: 0.9853 - val_loss: 0.1082 - val_accuracy: 0.9778
# Epoch 39/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0467 - accuracy: 0.9857 - val_loss: 0.1189 - val_accuracy: 0.9785
# Epoch 40/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0491 - accuracy: 0.9856 - val_loss: 0.1204 - val_accuracy: 0.9783
# Epoch 41/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0457 - accuracy: 0.9864 - val_loss: 0.1244 - val_accuracy: 0.9783
# Epoch 42/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0490 - accuracy: 0.9861 - val_loss: 0.1187 - val_accuracy: 0.9784
# Epoch 43/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0465 - accuracy: 0.9861 - val_loss: 0.1207 - val_accuracy: 0.9787
# Epoch 44/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0460 - accuracy: 0.9866 - val_loss: 0.1225 - val_accuracy: 0.9777
# Epoch 45/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0491 - accuracy: 0.9853 - val_loss: 0.1232 - val_accuracy: 0.9782
# Epoch 46/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0459 - accuracy: 0.9859 - val_loss: 0.1267 - val_accuracy: 0.9787
# Epoch 47/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0413 - accuracy: 0.9880 - val_loss: 0.1249 - val_accuracy: 0.9783
# Epoch 48/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0448 - accuracy: 0.9875 - val_loss: 0.1265 - val_accuracy: 0.9787
# Epoch 49/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0444 - accuracy: 0.9872 - val_loss: 0.1229 - val_accuracy: 0.9784
# Epoch 50/50
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0466 - accuracy: 0.9867 - val_loss: 0.1209 - val_accuracy: 0.9797

# %%
#evalute the model
test_loss, test_acc = model.evaluate(X_test, Y_test)
print('Test accuracy:', test_acc)

# making prediction
predictions = model.predict(X_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1046 - accuracy: 0.9811
# Test accuracy: 0.9811000227928162
# 313/313 [==============================] - 1s 1ms/step

# %% [markdown]
# increasing validation loss implies that model has started to overfit

# %%
import matplotlib.pyplot as plt
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend(loc="upper right")
plt.show()

# %%
plt.plot(r.history['accuracy'], label='acc')
plt.plot(r.history['val_accuracy'], label='val_acc')
plt.legend(loc="upper right")
plt.show()
