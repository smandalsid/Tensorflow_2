# %% [markdown]
# changing the number of internal hidden neurons

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# network and training
EPOCHS = 20
BATCH_SIZE = 256
VERBOSE = 1
NB_CLASSES = 10   # number of outputs = number of digits
N_HIDDEN = 512
VALIDATION_SPLIT=0.2 # how much TRAIN is reserved for VALIDATION
DROPOUT = 0.3

# loading MNIST dataset
# verify
# the split between train and test is 60,000, and 10,000 respectly
# one-hot is automatically applied
mnist = keras.datasets.mnist
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

#X_train is 60000 rows of 28x28 values --> reshaped in 60000 x 784
RESHAPED = 784
#
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

#normalize in [0,1]
X_train, X_test = X_train / 255.0, X_test / 255.0
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

#one-hot
Y_train = tf.keras.utils.to_categorical(Y_train, NB_CLASSES)
Y_test = tf.keras.utils.to_categorical(Y_test, NB_CLASSES)

#build the model
model = tf.keras.models.Sequential()
model.add(keras.layers.Dense(N_HIDDEN,
   		input_shape=(RESHAPED,),
   		name='dense_layer', activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(N_HIDDEN,
   		name='dense_layer_2', activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(NB_CLASSES,
   		name='dense_layer_3', activation='softmax'))

# summary of the model
model.summary()

# compiling the model
model.compile(optimizer='Adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

#training the moodel
r=model.fit(X_train, Y_train,
		batch_size=BATCH_SIZE, epochs=EPOCHS,
		verbose=VERBOSE, validation_split=VALIDATION_SPLIT)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# 60000 train samples
# 10000 test samples
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_layer (Dense)         (None, 512)               401920
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_layer_2 (Dense)       (None, 512)               262656
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_layer_3 (Dense)       (None, 10)                5130
#
# =================================================================
# Total params: 669,706
# Trainable params: 669,706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 188/188 [==============================] - 10s 10ms/step - loss: 0.3606 - accuracy: 0.8906 - val_loss: 0.1513 - val_accuracy: 0.9550
# Epoch 2/20
# 188/188 [==============================] - 1s 7ms/step - loss: 0.1410 - accuracy: 0.9581 - val_loss: 0.1024 - val_accuracy: 0.9684
# Epoch 3/20
# 188/188 [==============================] - 1s 8ms/step - loss: 0.1018 - accuracy: 0.9686 - val_loss: 0.0909 - val_accuracy: 0.9730
# Epoch 4/20
# 188/188 [==============================] - 1s 8ms/step - loss: 0.0790 - accuracy: 0.9757 - val_loss: 0.0804 - val_accuracy: 0.9748
# Epoch 5/20
# 188/188 [==============================] - 1s 7ms/step - loss: 0.0628 - accuracy: 0.9801 - val_loss: 0.0775 - val_accuracy: 0.9768
# Epoch 6/20
# 188/188 [==============================] - 1s 5ms/step - loss: 0.0535 - accuracy: 0.9835 - val_loss: 0.0758 - val_accuracy: 0.9766
# Epoch 7/20
# 188/188 [==============================] - 1s 4ms/step - loss: 0.0442 - accuracy: 0.9859 - val_loss: 0.0768 - val_accuracy: 0.9773
# Epoch 8/20
# 188/188 [==============================] - 1s 7ms/step - loss: 0.0388 - accuracy: 0.9871 - val_loss: 0.0730 - val_accuracy: 0.9813
# Epoch 9/20
# 188/188 [==============================] - 1s 7ms/step - loss: 0.0360 - accuracy: 0.9881 - val_loss: 0.0776 - val_accuracy: 0.9785
# Epoch 10/20
# 188/188 [==============================] - 1s 5ms/step - loss: 0.0318 - accuracy: 0.9894 - val_loss: 0.0726 - val_accuracy: 0.9814
# Epoch 11/20
# 188/188 [==============================] - 1s 4ms/step - loss: 0.0274 - accuracy: 0.9906 - val_loss: 0.0842 - val_accuracy: 0.9787
# Epoch 12/20
# 188/188 [==============================] - 1s 5ms/step - loss: 0.0278 - accuracy: 0.9899 - val_loss: 0.0775 - val_accuracy: 0.9797
# Epoch 13/20
# 188/188 [==============================] - 1s 4ms/step - loss: 0.0244 - accuracy: 0.9923 - val_loss: 0.0754 - val_accuracy: 0.9806
# Epoch 14/20
# 188/188 [==============================] - 1s 4ms/step - loss: 0.0231 - accuracy: 0.9918 - val_loss: 0.0854 - val_accuracy: 0.9792
# Epoch 15/20
# 188/188 [==============================] - 1s 4ms/step - loss: 0.0214 - accuracy: 0.9930 - val_loss: 0.0856 - val_accuracy: 0.9804
# Epoch 16/20
# 188/188 [==============================] - 1s 4ms/step - loss: 0.0204 - accuracy: 0.9929 - val_loss: 0.0893 - val_accuracy: 0.9793
# Epoch 17/20
# 188/188 [==============================] - 1s 4ms/step - loss: 0.0200 - accuracy: 0.9932 - val_loss: 0.0835 - val_accuracy: 0.9802
# Epoch 18/20
# 188/188 [==============================] - 1s 4ms/step - loss: 0.0212 - accuracy: 0.9927 - val_loss: 0.0834 - val_accuracy: 0.9810
# Epoch 19/20
# 188/188 [==============================] - 1s 4ms/step - loss: 0.0177 - accuracy: 0.9940 - val_loss: 0.0833 - val_accuracy: 0.9803
# Epoch 20/20
# 188/188 [==============================] - 1s 4ms/step - loss: 0.0178 - accuracy: 0.9940 - val_loss: 0.0841 - val_accuracy: 0.9803

# %%
#evalute the model
test_loss, test_acc = model.evaluate(X_test, Y_test)
print('Test accuracy:', test_acc)

# making prediction
predictions = model.predict(X_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0768 - accuracy: 0.9815
# Test accuracy: 0.9815000295639038
# 313/313 [==============================] - 1s 1ms/step

# %%
import matplotlib.pyplot as plt
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend(loc="upper right")
plt.show()

# %%
plt.plot(r.history['accuracy'], label='acc')
plt.plot(r.history['val_accuracy'], label='val_acc')
plt.legend(loc="upper right")
plt.show()
